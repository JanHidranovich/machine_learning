# %% [markdown]
# <a href="https://colab.research.google.com/github/JanHidranovich/machine_learning/blob/main/linear_regr_wine_qu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.inspection import permutation_importance

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/linear/winequality-red.csv')
df = pd.DataFrame(dataset)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
target = df['quality']

# %%
features = df.drop("quality", axis = 1)
features
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
model = LinearRegression()
model.fit(features, target)
# Out:
# LinearRegression()

# %%
r_sq = model.score(features, target)
r_sq
# Out:
# 0.3605517030386879

# %%
print(model.intercept_, model.coef_)
# Out:
# 21.965208449448532 [ 2.49905527e-02 -1.08359026e+00 -1.82563948e-01  1.63312698e-02
#  -1.87422516e+00  4.36133331e-03 -3.26457970e-03 -1.78811638e+01
#  -4.13653144e-01  9.16334413e-01  2.76197699e-01]

# %%
target_pred = model.predict(features).round()

# %%
target_pred
# Out:
# array([5., 5., 5., ..., 6., 5., 6.])

# %%
target_arr = np.array(df['quality'])

# %%
err = abs(target_arr - target_pred)

# %%
acc = np.count_nonzero(target_arr == target_pred) / len(err)
print(acc)
# Out:
# 0.5916197623514696

# %%
acc1 = np.count_nonzero(target_arr - target_pred <= 1) / len(err)
print(acc1)
# Out:
# 0.9887429643527205

# %%
feature_importances = permutation_importance(model, features, target)
feature_importances = pd.DataFrame(feature_importances['importances_mean'], index=features.columns.tolist(), columns=['importance'])
feature_importances.sort_values('importance', ascending=False)
# Out:
#                       importance
# alcohol                 0.259795
# volatile acidity        0.112009
# sulphates               0.069938
# total sulfur dioxide    0.037308
# chlorides               0.025084
# pH                      0.009571
# free sulfur dioxide     0.005659
# citric acid             0.005545
# fixed acidity           0.004720
# density                 0.004334
# residual sugar          0.001508

# %%
features_cut = df.drop(["residual sugar", "citric acid", "density", "fixed acidity", "free sulfur dioxide", "quality"], axis=1)
features_cut
# Out:
#       volatile acidity  chlorides  total sulfur dioxide    pH  sulphates  \
# 0                0.700      0.076                  34.0  3.51       0.56
# 1                0.880      0.098                  67.0  3.20       0.68
# 2                0.760      0.092                  54.0  3.26       0.65
# 3                0.280      0.075                  60.0  3.16       0.58
# 4                0.700      0.076                  34.0  3.51       0.56
# ...                ...        ...                   ...   ...        ...
# 1594             0.600      0.090                  44.0  3.45       0.58
# 1595             0.550      0.062                  51.0  3.52       0.76
# 1596             0.510      0.076                  40.0  3.42       0.75
# 1597             0.645      0.075                  44.0  3.57       0.71
# 1598             0.310      0.067                  42.0  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 6 columns]

# %%
model.fit(features_cut, target)
r_sq = model.score(features_cut, target)
r_sq
# Out:
# 0.35717364800893114

# %%
feature_importances_cut = permutation_importance(model, features_cut, target)
feature_importances_cut = pd.DataFrame(feature_importances_cut['importances_mean'], index=features_cut.columns.tolist(), columns=['importance'])
feature_importances_cut.sort_values('importance', ascending=False)
# Out:
#                       importance
# alcohol                 0.287595
# volatile acidity        0.100844
# sulphates               0.066532
# chlorides               0.027848
# total sulfur dioxide    0.017525
# pH                      0.014247
